# %%
import pandas as pd

# %%
# read the entire file into a python array
with open("D:\\NLP\\Apps_for_Android_5.json", 'rU') as f:
   data = f.readlines()
#print(data)

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = "[" + ",".join(data) + "]"

# now, load it into pandas
df = pd.read_json(data_json_str)
# Out:
# C:\Users\vkatepally\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: 'U' mode is deprecated

# %%
print(df.head())
# Out:
#          asin helpful  overall  \
# 0  B004A9SDD8  [1, 1]        3
# 1  B004A9SDD8  [0, 0]        5
# 2  B004A9SDD8  [0, 0]        5
# 3  B004A9SDD8  [3, 4]        5
# 4  B004A9SDD8  [1, 1]        5
#
#                                           reviewText   reviewTime  \
# 0  Loves the song, so he really couldn't wait to ...   11 2, 2013
# 1  Oh, how my little grandson loves this app. He'...   12 5, 2011
# 2  I found this at a perfect time since my daught...  05 21, 2012
# 3  My 1 year old goes back to this game over and ...   12 6, 2012
# 4  There are three different versions of the song...   02 1, 2014
#
#        reviewerID                   reviewerName  \
# 0  A1N4O8VOJZTDVB                 Annette Yancey
# 1  A2HQWU6HUKIEC7        Audiobook lover "Kathy"
# 2  A1SXASF6GYG96I                  Barbara Gibbs
# 3  A2B54P9ZDYH167  Brooke Greenstreet "Babylove"
# 4   AFOFZDTX5UC6D                     C. Galindo
#
#                                              summary  unixReviewTime
# 0                                        Really cute      1383350400
# 1                                2-year-old loves it      1323043200
# 2                                           Fun game      1337558400
# 3                               We love our Monkeys!      1354752000
# 4  This is my granddaughters favorite app on my K...      1391212800

# %%
#dataframe size
df.shape
# Out:
# (752937, 9)

# %%
#drop duplicates if any

df.drop_duplicates(subset=["reviewerID","reviewTime"],keep='first')
#size
df.shape
#therefore there are no duplicates
# Out:
# (752937, 9)

# %%
#finding the null values if any
df.isnull().sum()
#reviewr name has some null values but that doesn't affect our model so we need not impute any values
# Out:
# asin                  0
# helpful               0
# overall               0
# reviewText            0
# reviewTime            0
# reviewerID            0
# reviewerName      58198
# summary               0
# unixReviewTime        0
# dtype: int64

# %%
#df['overall'].describe()
#dropping all the columns except reviewText and overall because the data relevant to sentiment analysis is present in this columns only
df_updated=df.drop(columns=["asin","helpful","reviewTime","reviewerID","reviewerName","summary","unixReviewTime"])
df_updated
# Out:
#         overall                                         reviewText
# 0             3  Loves the song, so he really couldn't wait to ...
# 1             5  Oh, how my little grandson loves this app. He'...
# 2             5  I found this at a perfect time since my daught...
# 3             5  My 1 year old goes back to this game over and ...
# 4             5  There are three different versions of the song...
# 5             5  THis is just so cute and a great app for littl...
# 6             5  I watch my great grandson 4 days a week and it...
# 7             5  This app is wild and crazy.  Little ones love ...
# 8             5  love love love this app. I was going through d...
# 9             5  Very cute, with alot of items to move about.  ...
# 10            4  WELL THE CHILDREN LOVE IT AFTER AWHILE YOU GET...
# 11            3  I got this app because my 2 year old daughter ...
# 12            5  My three year old Plays this game the most he ...
# 13            3  Good for little ones, especially if  know the ...
# 14            5  My two year old grandson loves this game and p...
# 15            5  My granddaughter really loves this. She will l...
# 16            4  love it, but wish it was fullscreen on honeyco...
# 17            1  does not let you sample only for a sec. if you...
# 18            5  this is a very good app and it you need this s...
# 19            4  It's easy to use and transfer songs. If I purc...
# 20            4  Great selections.  Easy to use interface.  I h...
# 21            5  I really don't think I could live without Rhap...
# 22            5  I love this app!! Yes,after 14 days you have t...
# 23            5  If you pay for the subscription then by all me...
# 24            1  Tried to run this on my Kindle Fire; kept givi...
# 25            5  We love Rhapsody we use it all the time. Affor...
# 26            1  It just doesn't do what I needed it to do.  Fo...
# 27            5  I Have to Say that of All of the Many Other Mu...
# 28            5  I have been a Rhapsody susbscriber for many ye...
# 29            5  I have used most every subscription music serv...
# ...         ...                                                ...
# 752907        5  If you are familiar with Cubistry, the game th...
# 752908        5  It is all that in a free magazine. I read the ...
# 752909        4  Love Joel and Victoria Osteen! This magazine i...
# 752910        5  As I expected a wonderful read, came @ a time ...
# 752911        5  I need hope everyday while I've been going thr...
# 752912        5  kind of an unfair advantage for me seeing I wa...
# 752913        5  This game is much better than any of the other...
# 752914        5  This game is one of the most realistic dinosau...
# 752915        5  I somewhat enjoyed Deer Hunter, but this?!? Th...
# 752916        4  I just got this game and I'm doing alright wit...
# 752917        5  The tutorial is excellent, smooth graphics, ni...
# 752918        5  I've used other hunting games and this is by f...
# 752919        5  This is the best game ever but if they could a...
# 752920        5  Fun, addictive, hard to stop playing.  This ga...
# 752921        4         Great game but liked jewels star 2 better.
# 752922        5  Most fun and challenging, greatest time waster...
# 752923        5  Another great Jewels game which keeps you thin...
# 752924        5  I enjoy the variety of both timed and untimed ...
# 752925        5  I highly recommend this game it is very intrig...
# 752926        5  This game is so addictive!  Just can't stop pl...
# 752927        5                            Really like the game!!!
# 752928        5  This is a great game. Graphics wonderfully sha...
# 752929        5  Great Game! Very similar to Gems journey. You ...
# 752930        5  This game is fun but more difficult as you com...
# 752931        5  Jewels 3 is just as AWESOME  as 1 and 2 . Mayb...
# 752932        5  I love it!!!!!!!!!!  really keeps your attenti...
# 752933        3  Okay but there are so many free ones that are ...
# 752934        4  Another great jewels game that just keeps you ...
# 752935        5  I find this the best jewels star ever. There s...
# 752936        4  This game was fun to play but was not as good ...
#
# [752937 rows x 2 columns]

# %%
#now our dataframe consists of only 2 columns which has review text and rating
#we have to convert the overall column to the values of 0 and 1 because sentiment of a text will be either positive or negative 
#Values greater than or equal to 3 are considered positive and less than 3 are negative

def f(x):
    if(x>=3):
        return 1
    else:
        return 0

df_updated["Rating"]=df_updated['overall'].apply(f)

# %%
df_updated.columns
final_df=df_updated.drop(columns=["overall"])
final_df
# Out:
#                                                reviewText  Rating
# 0       Loves the song, so he really couldn't wait to ...       1
# 1       Oh, how my little grandson loves this app. He'...       1
# 2       I found this at a perfect time since my daught...       1
# 3       My 1 year old goes back to this game over and ...       1
# 4       There are three different versions of the song...       1
# 5       THis is just so cute and a great app for littl...       1
# 6       I watch my great grandson 4 days a week and it...       1
# 7       This app is wild and crazy.  Little ones love ...       1
# 8       love love love this app. I was going through d...       1
# 9       Very cute, with alot of items to move about.  ...       1
# 10      WELL THE CHILDREN LOVE IT AFTER AWHILE YOU GET...       1
# 11      I got this app because my 2 year old daughter ...       1
# 12      My three year old Plays this game the most he ...       1
# 13      Good for little ones, especially if  know the ...       1
# 14      My two year old grandson loves this game and p...       1
# 15      My granddaughter really loves this. She will l...       1
# 16      love it, but wish it was fullscreen on honeyco...       1
# 17      does not let you sample only for a sec. if you...       0
# 18      this is a very good app and it you need this s...       1
# 19      It's easy to use and transfer songs. If I purc...       1
# 20      Great selections.  Easy to use interface.  I h...       1
# 21      I really don't think I could live without Rhap...       1
# 22      I love this app!! Yes,after 14 days you have t...       1
# 23      If you pay for the subscription then by all me...       1
# 24      Tried to run this on my Kindle Fire; kept givi...       0
# 25      We love Rhapsody we use it all the time. Affor...       1
# 26      It just doesn't do what I needed it to do.  Fo...       0
# 27      I Have to Say that of All of the Many Other Mu...       1
# 28      I have been a Rhapsody susbscriber for many ye...       1
# 29      I have used most every subscription music serv...       1
# ...                                                   ...     ...
# 752907  If you are familiar with Cubistry, the game th...       1
# 752908  It is all that in a free magazine. I read the ...       1
# 752909  Love Joel and Victoria Osteen! This magazine i...       1
# 752910  As I expected a wonderful read, came @ a time ...       1
# 752911  I need hope everyday while I've been going thr...       1
# 752912  kind of an unfair advantage for me seeing I wa...       1
# 752913  This game is much better than any of the other...       1
# 752914  This game is one of the most realistic dinosau...       1
# 752915  I somewhat enjoyed Deer Hunter, but this?!? Th...       1
# 752916  I just got this game and I'm doing alright wit...       1
# 752917  The tutorial is excellent, smooth graphics, ni...       1
# 752918  I've used other hunting games and this is by f...       1
# 752919  This is the best game ever but if they could a...       1
# 752920  Fun, addictive, hard to stop playing.  This ga...       1
# 752921         Great game but liked jewels star 2 better.       1
# 752922  Most fun and challenging, greatest time waster...       1
# 752923  Another great Jewels game which keeps you thin...       1
# 752924  I enjoy the variety of both timed and untimed ...       1
# 752925  I highly recommend this game it is very intrig...       1
# 752926  This game is so addictive!  Just can't stop pl...       1
# 752927                            Really like the game!!!       1
# 752928  This is a great game. Graphics wonderfully sha...       1
# 752929  Great Game! Very similar to Gems journey. You ...       1
# 752930  This game is fun but more difficult as you com...       1
# 752931  Jewels 3 is just as AWESOME  as 1 and 2 . Mayb...       1
# 752932  I love it!!!!!!!!!!  really keeps your attenti...       1
# 752933  Okay but there are so many free ones that are ...       1
# 752934  Another great jewels game that just keeps you ...       1
# 752935  I find this the best jewels star ever. There s...       1
# 752936  This game was fun to play but was not as good ...       1
#
# [752937 rows x 2 columns]

# %%
final_df["Rating"].value_counts()
# Out:
# 1    629839
# 0    123098
# Name: Rating, dtype: int64

# %%
print(len(final_df["reviewText"].values))
# Out:
# 752937

# %% [markdown]
# # PreProcessing of reviews

# %%
#Removal of URL's if any
import re
sample_text='hello  https://www.google.com/'

sample_text=re.sub(r"http\S+", "",sample_text)
print(sample_text)
# Out:
# hello

# %%
#Removal of html tags if any

from bs4 import BeautifulSoup
sample_Text='hello <br> </br> hi'

soup = BeautifulSoup(sample_Text, 'lxml')
text = soup.get_text()
print(text)
# Out:
# hello   hi

# %%
#Expanding English language contractions in Python and smiley
def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    #phrase = re.sub(r":)", "happy", phrase)
    phrase=phrase.replace(":)","good")

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

print(decontracted("hi i am happy :) "))
# Out:
# hi i am happy good

# %%
#Removing html characters
import html
print(html.unescape('&#34;'))

# %%
# Combining all the above stundents .
import html
from tqdm import tqdm
preprocessed_reviews = []
# tqdm is for printing the status bar
for sentance in tqdm(final_df['reviewText'].values):
    html.unescape(sentance)
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    preprocessed_reviews.append(sentance.strip())

# %%
import html
print(html.unescape('&#34;'))
# Out:
# "
